# %% [markdown]
# # Lecture 2 Notes: Loops, conditionals, dictionaries, and sets

# %% [markdown]
# ### Data from Pre-course Questionaire

# %%
from IPython.display import Image
Image("precourse_questionaire_data.png", width=600)

# %% [markdown]
# # Writing loops in Python
# 3 ways to run `for` loop (over a list)

# %%
numbers = [2,3,4,5,6,7,8]

# write a loop to print 1 plus each number in the list

# %%
more_numbers = [9,10,11,12,13,14,15]

# write a loop to add the values of each list together

# %%
# rewrite the loop using the 'zip' function to combine the two lists

# %%
before = [0,23,34,15,21] #data before some sort of treatment
after = [12,43,50,29,67] #data after some sort of treatment in mice (gene expression, time on hamster wheel, etc)

differences = []

# write a loop to find the difference between each data point in the two lists

# %%
differences = []

# rewrite the loop using the 'zip' function to combine the two lists

# %%
differences = []
control = [0,0,2,1,1]

# write a loop to

# %% [markdown]
# ### `if` Statements

# %%
x = 1

if x>0:
    print('my experiment worked')

# %%
x = True      #boolean data types - not a number, not a text string, just represents either true or false, 0 or 1

if x:
    print('my experiment worked')

# %%
genes = ['miRNA', 'mRNA', 'lncRNA']

# check if 'miRNA' is in the list

# %%
genes = ['miRNA', 'mRNA', 'lncRNA']

gene = 'mRNA'

# check if the variable 'gene' is in the list

# %%
genes = ['miRNA', 'mRNA', 'lncRNA']

gene = 'tRNA'


# check if the variable 'gene' is in the list, and print a message if it is or isn't

# %%
genes = ['miRNA', 'mRNA', 'lncRNA']

gene = 'tRNA'

if gene in genes:
    print(gene, 'is present')
elif 'lncRNA' in genes:             #else if statement: 'elif' in python
    print('lncRNA is present')
else:
    print(gene, 'is not present')

# %% [markdown]
# ### Strings vs Lists

# %%
a_string = 'python'

# print out each letter in the string using a for loop

# %%
# print the first letter of a string using indexing

# %% [markdown]
# ### Dictionaries
# Dictionaries are unordered collection of 'keys' and 'values'

# %%
organisms = ['yeast', 'flies', 'worms', 'mice']
organisms[1]

# %%
# This is a dictionary. It is like a list, but instead of indexing with numbers, you index with words
coding_genes = {'yeast':5889, 'worms': 25244, 'flies': 13931, 'mice': 2195}

# %%
# Print the number of coding genes in yeast

# %%
# Check if you can index into a dictionary with a number

# %%
# print the number of key-value pairs in the dictionary

# %%
# loop over the items in the dictionary and print the key and value

# %%
# loop over dictionary using .items() method

# %%
# analyze the output of the .items() method

# %%
# print the keys of the dictionary

# %%
# sort the keys of the dictionary alphabetically

# %%
# loop over the sorted keys

# %%
# loop over the sorted items
sorted(coding_genes.items())

# %%
# try to append 'gorilla' to the dictionary

# %%
# try to add the key-value pair 'gorilla': 20962 to the dictionary

# %%
# how to modify exisiting the value of yeast to be 5890

# %%
# check if 'chicken' is in the dictionary, if it is not, add it with a value of 18346

# %% [markdown]
# ## Sets
# unordered collection of items in python,
# removes all redudancys

# %%
datasets = ['yeast', 'yeast', 'flies', 'mice', 'worms']

# %%
# get the unique values in the list using the set() function
